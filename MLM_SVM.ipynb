# %%
#!pip install mlxtend 
import numpy as np 
import pandas as pd 
import matplotlib as plt 
from sklearn import datasets 
from sklearn.model_selection import train_test_split
from sklearn import svm
from mlxtend.plotting import plot_decision_regions

# %%
iris = datasets.load_iris()

# %%
iris_df = pd.DataFrame(iris.data, columns=iris.feature_names)
iris_df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2

# %%
sepal_length = iris['data'][:, 0]
petal_length = iris['data'][:, 2]

# %%
X = np.column_stack((sepal_length, petal_length))
y = iris.target

x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %% [markdown]
# ## Under you will see different kernels. Feel free to simply uncomment a specific line to test different kernels.

# %%
# clf = svm.SVC()
# clf = svm.SVC(kernel = 'linear', C = 1)
# clf = svm.SVC(kernel = 'rbf', C = 1)
# clf = svm.SVC(kernel = 'poly', C = 1)
# clf = svm.SVC(kernel = 'sigmoid', C = 1)

# clf = svm.NuSVC(gamma='auto')
clf.fit(x_train, y_train)
# Out:
# NuSVC(cache_size=200, class_weight=None, coef0=0.0,
#       decision_function_shape=&#39;ovr&#39;, degree=3, gamma=&#39;auto&#39;, kernel=&#39;rbf&#39;,
#       max_iter=-1, nu=0.5, probability=False, random_state=None, shrinking=True,
#       tol=0.001, verbose=False)

# %%
print('Training accuracy: ', clf.score(x_train, y_train))
print('Testing accuracy: ', clf.score(x_test, y_test))
# Out:
# Training accuracy:  0.925
# Testing accuracy:  0.9666666666666667

# %%
# Plotting training set 
plot_decision_regions(X = x_train, y = y_train, clf = clf, legend = 1)
# Out:
# &lt;matplotlib.axes._subplots.AxesSubplot at 0x1b992a65448&gt;
# &lt;Figure size 432x288 with 1 Axes&gt;

# %%
# Plotting test set
plot_decision_regions(X = x_test, y = y_test, clf = clf, legend = 1)
# Out:
# &lt;matplotlib.axes._subplots.AxesSubplot at 0x1b992aa8208&gt;
# &lt;Figure size 432x288 with 1 Axes&gt;
